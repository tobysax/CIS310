# %% [markdown]
# # Toby Sax
# ## Week 16 - 12/5/2023
# ### Python Data Cleaning And Visulization Project: Python Stock market For Amazon

# %%
#normal import
import numpy as np
from numpy.random import randn
import pandas as pd

#these are the plotting modules and libnraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt

#command so that plots appear in the Ipython Notebook
# %matplotlib inline

# %%
#Upload dataset from a csv file
data = pd.read_csv('AMZN.csv')

# %%
# data info
data.head()
# Out:
#        Date Source        Open        High         Low       Close  \
# 0  1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1  1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2  1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3  1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4  1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
#
#     Adj Close   Volume   Stock
# 0  179.029999  5110800  amazon
# 1  177.509995  4205200  amazon
# 2  177.610001  3809100  amazon
# 3  182.610001  7008400  amazon
# 4  178.559998  5056900  amazon

# %%
data.tail()
# Out:
#             Date Source         Open         High          Low        Close  \
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# 2237  3099.399902  3374400  amazon
# 2238  3098.389893  4708900  amazon
# 2239  3118.060059  3602100  amazon
# 2240  3185.070068  3790400  amazon
# 2241  3195.340088  2392900  amazon

# %%
data.head(10)
# Out:
#         Date Source        Open        High         Low       Close  \
# 0   1/3/2012  yahoo  175.889999  179.479996  175.550003  179.029999
# 1   1/4/2012  yahoo  179.210007  180.500000  176.070007  177.509995
# 2   1/5/2012  yahoo  175.940002  178.250000  174.050003  177.610001
# 3   1/6/2012  yahoo  178.070007  184.649994  177.500000  182.610001
# 4   1/9/2012  yahoo  182.759995  184.369995  177.000000  178.559998
# 5  1/10/2012  yahoo  181.100006  182.399994  177.100006  179.339996
# 6  1/11/2012  yahoo  179.639999  180.770004  178.190002  178.899994
# 7  1/12/2012  yahoo  179.419998  179.490005  175.750000  175.929993
# 8  1/13/2012  yahoo  175.809998  178.800003  173.500000  178.419998
# 9  1/17/2012  yahoo  180.149994  183.300003  178.509995  181.660004
#
#     Adj Close   Volume   Stock
# 0  179.029999  5110800  amazon
# 1  177.509995  4205200  amazon
# 2  177.610001  3809100  amazon
# 3  182.610001  7008400  amazon
# 4  178.559998  5056900  amazon
# ...

# %%
data.tail(15)
# Out:
#             Date Source         Open         High          Low        Close  \
# 2227   11/6/2020  yahoo  3304.639893  3322.000000  3232.000000  3311.370117
# 2228   11/9/2020  yahoo  3231.030029  3289.000000  3112.110107  3143.739990
# 2229  11/10/2020  yahoo  3095.020020  3114.000000  3019.479980  3035.020020
# 2230  11/11/2020  yahoo  3061.780029  3139.149902  3050.000000  3137.389893
# 2231  11/12/2020  yahoo  3159.949951  3175.879883  3086.050049  3110.280029
# 2232  11/13/2020  yahoo  3122.000000  3141.719971  3085.389893  3128.810059
# 2233  11/16/2020  yahoo  3093.199951  3142.699951  3072.689941  3131.060059
# 2234  11/17/2020  yahoo  3183.540039  3189.250000  3135.260010  3135.659912
# 2235  11/18/2020  yahoo  3134.000000  3140.000000  3105.100098  3105.459961
# 2236  11/19/2020  yahoo  3105.310059  3125.000000  3080.919922  3117.020020
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# ...

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2241.000000  2240.000000  2242.000000  2239.000000  2241.000000
# mean    991.401419  1002.190218   979.221717   991.895355   991.190696
# std     802.269032   811.968123   790.843600   801.664757   801.654109
# min     173.809998   178.250000   172.000000   175.929993   175.929993
# 25%     320.359985   323.687500   315.807487   321.385010   320.510010
# 50%     717.380005   723.394989   712.629975   719.299988   719.070007
# 75%    1660.000000  1679.964966  1633.707459  1661.830017  1660.510010
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.242000e+03
# mean   4.118187e+06
# std    2.278888e+06
# min    0.000000e+00
# 25%    2.688550e+06
# 50%    3.528700e+06
# 75%    4.839800e+06
# max    2.385610e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2242 non-null   object
#  1   Source     2242 non-null   object
#  2   Open       2241 non-null   float64
#  3   High       2240 non-null   float64
#  4   Low        2242 non-null   float64
#  5   Close      2239 non-null   float64
#  6   Adj Close  2241 non-null   float64
#  7   Volume     2242 non-null   int64
#  8   Stock      2242 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 157.8+ KB

# %%
data.shape
# Out:
# (2242, 9)

# %%
data.columns
# Out:
# Index(['Date', 'Source', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Stock'],
#       dtype='object')

# %%
data['Adj Close'].plot()

# %%
data['Adj Close'].plot(legend=True, figsize=(10,4))

# %%
#count the number of numerical and none-numerical variables (columns)
from pandas.api.types import is_numeric_dtype

n=0
for c in data.columns:
    if is_numeric_dtype(data[c]):
        n+=1
        
print(f'numerical variables: {n}, and non-numerical variables: {len(data.columns)-n}')
# Out:
# numerical variables: 6, and non-numerical variables: 3

# %%
#data cleaning - Preparing data for analytics, missing data
len(data.columns)
# Out:
# 9

# %%
data.isnull()
# Out:
#        Date  Source   Open   High    Low  Close  Adj Close  Volume  Stock
# 0     False   False  False  False  False  False      False   False  False
# 1     False   False  False  False  False  False      False   False  False
# 2     False   False  False  False  False  False      False   False  False
# 3     False   False  False  False  False  False      False   False  False
# 4     False   False  False  False  False  False      False   False  False
# ...     ...     ...    ...    ...    ...    ...        ...     ...    ...
# 2237  False   False  False  False  False  False      False   False  False
# 2238  False   False  False  False  False  False      False   False  False
# 2239  False   False  False  False  False  False      False   False  False
# 2240  False   False  False  False  False  False      False   False  False
# 2241  False   False  False  False  False  False      False   False  False
#
# [2242 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         1
# High         2
# Low          0
# Close        3
# Adj Close    1
# Volume       0
# Stock        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Date         0
# Source       0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Stock        0
# dtype: int64

# %%
data.isnull()
# Out:
#        Date  Source   Open   High    Low  Close  Adj Close  Volume  Stock
# 0     False   False  False  False  False  False      False   False  False
# 1     False   False  False  False  False  False      False   False  False
# 2     False   False  False  False  False  False      False   False  False
# 3     False   False  False  False  False  False      False   False  False
# 4     False   False  False  False  False  False      False   False  False
# ...     ...     ...    ...    ...    ...    ...        ...     ...    ...
# 2237  False   False  False  False  False  False      False   False  False
# 2238  False   False  False  False  False  False      False   False  False
# 2239  False   False  False  False  False  False      False   False  False
# 2240  False   False  False  False  False  False      False   False  False
# 2241  False   False  False  False  False  False      False   False  False
#
# [2235 rows x 9 columns]

# %%
#clean abnormal values
data['Volume'].plot(kind='hist',bins=50)

# %%
data['Volume']
# Out:
# 0       5110800
# 1       4205200
# 2       3809100
# 3       7008400
# 4       5056900
#          ...
# 2237    3374400
# 2238    4708900
# 2239    3602100
# 2240    3790400
# 2241    2392900
# Name: Volume, Length: 2235, dtype: int64

# %%
data['Volume'].min()
# Out:
# 0

# %%
data['Volume'].max()
# Out:
# 23856100

# %%
data['Volume'].sort_values()
# Out:
# 29            0
# 114           1
# 18            5
# 161           6
# 47           23
#          ...
# 707    19801100
# 20     21336600
# 894    21909400
# 80     22116900
# 773    23856100
# Name: Volume, Length: 2235, dtype: int64

# %%
data['Volume'].sort_values().head(20)
# Out:
# 29            0
# 114           1
# 18            5
# 161           6
# 47           23
# 90           25
# 66           78
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# Name: Volume, dtype: int64

# %%
data=data[data['Volume'] > 100000]

# %%
data['Volume'].sort_values().head(20)
# Out:
# 2007     881300
# 245      984400
# 1001    1091200
# 126     1331700
# 879     1343400
# 426     1350600
# 376     1373000
# 497     1380400
# 405     1415000
# 411     1422600
# 415     1457100
# 1164    1458800
# 403     1504500
# 749     1513800
# 1167    1524100
# 151     1534300
# 417     1534700
# 152     1548100
# 1160    1563300
# 416     1566400
# Name: Volume, dtype: int64

# %%
#remove all columns that have a constant/single value
constant_columns=[]

for c in data.columns:
    n = len(data[c].unique())
    if n == 1:
        constant_columns.append(c)
        
print(f"constatn columns: {constant_columns}")
# Out:
# constatn columns: ['Source', 'Stock']

# %%
data
# Out:
#             Date Source         Open         High          Low        Close  \
# 0       1/3/2012  yahoo   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012  yahoo   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012  yahoo   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012  yahoo   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012  yahoo   182.759995   184.369995   177.000000   178.559998
# ...          ...    ...          ...          ...          ...          ...
# 2237  11/20/2020  yahoo  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  yahoo  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  yahoo  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  yahoo  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  yahoo  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume   Stock
# ...

# %%
data.drop(columns=constant_columns, axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume
# 0      179.029999  5110800
# 1      177.509995  4205200
# 2      177.610001  3809100
# ...

# %%
#adding year, month, day columns to the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 139.2+ KB

# %%
dateObject = pd.DatetimeIndex(data['Date'])
dateObject
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2020-11-13', '2020-11-16', '2020-11-17', '2020-11-18',
#                '2020-11-19', '2020-11-20', '2020-11-23', '2020-11-24',
#                '2020-11-25', '2020-11-27'],
#               dtype='datetime64[ns]', name='Date', length=2228, freq=None)

# %%
type(dateObject)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
data['Day'] = dateObject.day
data['Month'] = dateObject.month
data['Year'] = dateObject.year
data
# Out:
#             Date         Open         High          Low        Close  \
# 0       1/3/2012   175.889999   179.479996   175.550003   179.029999
# 1       1/4/2012   179.210007   180.500000   176.070007   177.509995
# 2       1/5/2012   175.940002   178.250000   174.050003   177.610001
# 3       1/6/2012   178.070007   184.649994   177.500000   182.610001
# 4       1/9/2012   182.759995   184.369995   177.000000   178.559998
# ...          ...          ...          ...          ...          ...
# 2237  11/20/2020  3117.020020  3132.889893  3098.050049  3099.399902
# 2238  11/23/2020  3116.699951  3139.750000  3065.459961  3098.389893
# 2239  11/24/2020  3100.500000  3134.250000  3086.260010  3118.060059
# 2240  11/25/2020  3141.870117  3198.000000  3140.260010  3185.070068
# 2241  11/27/2020  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close   Volume  Day  Month  Year
# 0      179.029999  5110800    3      1  2012
# 1      177.509995  4205200    4      1  2012
# ...

# %%
data[['Date','Day','Month','Year']]
# Out:
#             Date  Day  Month  Year
# 0       1/3/2012    3      1  2012
# 1       1/4/2012    4      1  2012
# 2       1/5/2012    5      1  2012
# 3       1/6/2012    6      1  2012
# 4       1/9/2012    9      1  2012
# ...          ...  ...    ...   ...
# 2237  11/20/2020   20     11  2020
# 2238  11/23/2020   23     11  2020
# 2239  11/24/2020   24     11  2020
# 2240  11/25/2020   25     11  2020
# 2241  11/27/2020   27     11  2020
#
# [2228 rows x 4 columns]

# %%
# Transform the values of Volume entries to represent thousands
data['Volume'] = data['Volume'] / 1000

# %%
data['Volume']
# Out:
# 0       5110.8
# 1       4205.2
# 2       3809.1
# 3       7008.4
# 4       5056.9
#          ...
# 2237    3374.4
# 2238    4708.9
# 2239    3602.1
# 2240    3790.4
# 2241    2392.9
# Name: Volume, Length: 2228, dtype: float64

# %%
#Use visulization for data analysis
data[['Year','Volume']]
# Out:
#       Year  Volume
# 0     2012  5110.8
# 1     2012  4205.2
# 2     2012  3809.1
# 3     2012  7008.4
# 4     2012  5056.9
# ...    ...     ...
# 2237  2020  3374.4
# 2238  2020  4708.9
# 2239  2020  3602.1
# 2240  2020  3790.4
# 2241  2020  2392.9
#
# [2228 rows x 2 columns]

# %%
data[['Year','Volume']].groupby('Year').sum().astype(int)
# Out:
#        Volume
# Year
# 2012   975492
# 2013   747905
# 2014  1029066
# 2015   957102
# 2016  1038756
# 2017   882705
# 2018  1417897
# 2019   974729
# 2020  1166035

# %%
group = data[['Year','Volume']].groupby('Year').sum().astype(int)
group
# Out:
#        Volume
# Year
# 2012   975492
# 2013   747905
# 2014  1029066
# 2015   957102
# 2016  1038756
# 2017   882705
# 2018  1417897
# 2019   974729
# 2020  1166035

# %%
type(group)
# Out:
# pandas.core.frame.DataFrame

# %%
group.plot(figsize=(8,6),y='Volume',fontsize=12,title="Stock's Volume Over Years")
plt.ylabel("Sock's Volume")
# Out:
# Text(0, 0.5, "Sock's Volume")

# %%
group = data[['Month','Volume']].groupby('Month').sum().astype(int)
group
# Out:
#        Volume
# Month
# 1      884620
# 2      846030
# 3      839584
# 4      890804
# 5      693382
# 6      671267
# 7      792035
# 8      633655
# 9      650017
# 10     897270
# 11     743073
# 12     647949

# %%
group.plot(figsize=(8,6),y='Volume',fontsize=12,title="Stock's Volume Over Months")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
group = data[['Day','Volume']].groupby('Day').sum().astype(int)
group
# Out:
#      Volume
# Day
# 1    296997
# 2    305034
# 3    289904
# 4    287930
# 5    297217
# 6    299634
# 7    284097
# 8    272722
# 9    298882
# 10   289759
# 11   284763
# 12   286916
# 13   304149
# 14   280092
# 15   299001
# 16   284345
# 17   292719
# 18   292270
# 19   287745
# 20   297045
# 21   287212
# 22   247224
# 23   287723
# 24   343586
# 25   303930
# 26   344153
# 27   370130
# 28   324011
# 29   307953
# 30   316127
# 31   226405

# %%
group.plot(figsize=(8,6),y='Volume',fontsize=12,title="Stock's Volume Over Days")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
group.plot.bar(figsize=(8,6),y='Volume',fontsize=12,title="Stock's Volume Over Days")
plt.ylabel("Stock's Volume")
# Out:
# Text(0, 0.5, "Stock's Volume")

# %%
#Show the cloasing per date.
rs = data[['Date','Adj Close']]

# %%
rs
# Out:
#             Date    Adj Close
# 0       1/3/2012   179.029999
# 1       1/4/2012   177.509995
# 2       1/5/2012   177.610001
# 3       1/6/2012   182.610001
# 4       1/9/2012   178.559998
# ...          ...          ...
# 2237  11/20/2020  3099.399902
# 2238  11/23/2020  3098.389893
# 2239  11/24/2020  3118.060059
# 2240  11/25/2020  3185.070068
# 2241  11/27/2020  3195.340088
#
# [2228 rows x 2 columns]

# %%
rs.plot(figsize=(10,8), x='Date', y='Adj Close', fontsize=12,title='Closing Price over the past 8 years')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   object
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Day        2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Year       2228 non-null   int64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 191.5+ KB

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%m/%d/%Y')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2228 entries, 0 to 2241
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2228 non-null   datetime64[ns]
#  1   Open       2228 non-null   float64
#  2   High       2228 non-null   float64
#  3   Low        2228 non-null   float64
#  4   Close      2228 non-null   float64
#  5   Adj Close  2228 non-null   float64
#  6   Volume     2228 non-null   float64
#  7   Day        2228 non-null   int64
#  8   Month      2228 non-null   int64
#  9   Year       2228 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 191.5 KB

# %%
data['Date']
# Out:
# 0      2012-01-03
# 1      2012-01-04
# 2      2012-01-05
# 3      2012-01-06
# 4      2012-01-09
#           ...
# 2237   2020-11-20
# 2238   2020-11-23
# 2239   2020-11-24
# 2240   2020-11-25
# 2241   2020-11-27
# Name: Date, Length: 2228, dtype: datetime64[ns]

# %%
#show the cloasing per date.
data[['Date','Adj Close']].plot(figsize=(10,8), x='Date', y='Adj Close', fontsize=12,title='Closing Price over the past 8 years')

# %%
#show the mean of the closing price over months
group = data[['Month', 'Adj Close']].groupby('Month').mean()
group
# Out:
#          Adj Close
# Month
# 1       837.217747
# 2       859.137411
# 3       873.045287
# 4       925.537783
# 5       973.608949
# 6      1020.935264
# 7      1105.226407
# 8      1114.643383
# 9      1123.582474
# 10     1119.413149
# 11     1102.657419
# 12      851.398673

# %%
group.plot(figsize=(10,8), y='Adj Close', fontsize=12,title='Closing Price over Months')
plt.ylabel('Ave of Adj Close')
# Out:
# Text(0, 0.5, 'Ave of Adj Close')

# %%
group = data[['Year', 'Adj Close']].groupby('Year').mean()
group
# Out:
#         Adj Close
# Year
# 2012   221.549534
# 2013   298.031588
# 2014   332.551033
# 2015   478.138295
# 2016   699.523135
# 2017   968.167012
# 2018  1641.726176
# 2019  1789.189206
# 2020  2629.294779

# %%
group.plot(figsize=(10,8), y='Adj Close', fontsize=12,title='Closing Price over Years')
plt.ylabel('Ave of Adj Close')
# Out:
# Text(0, 0.5, 'Ave of Adj Close')

# %%
#Using Filters
#find out & plot the adj close prices that are smaller than the Open prices, and after 2015
#First quert data for year > 2015
query1 = data[data['Year'] > 2015]
query1
# Out:
#            Date         Open         High          Low        Close  \
# 1006 2016-01-04   656.289978   657.719971   627.510010   636.989990
# 1007 2016-01-05   646.859985   646.909973   627.650024   633.789978
# 1008 2016-01-06   622.000000   639.789978   620.309998   632.650024
# 1009 2016-01-07   621.799988   630.000000   605.210022   607.940002
# 1010 2016-01-08   619.659973   624.140015   606.000000   607.049988
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 1006   636.989990  9314.5    4      1  2016
# 1007   633.789978  5822.6    5      1  2016
# ...

# %%
query1['Year']
# Out:
# 1006    2016
# 1007    2016
# 1008    2016
# 1009    2016
# 1010    2016
#         ...
# 2237    2020
# 2238    2020
# 2239    2020
# 2240    2020
# 2241    2020
# Name: Year, Length: 1236, dtype: int64

# %%
query1['Year'].min()
# Out:
# 2016

# %%
query1['Year'].max()
# Out:
# 2020

# %%
# query data for 'Adj Close' < 'Open' price
query2 = data[data['Adj Close']< data['Open']]
query2
# Out:
#            Date         Open         High          Low        Close  \
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# 5    2012-01-10   181.100006   182.399994   177.100006   179.339996
# 6    2012-01-11   179.639999   180.770004   178.190002   178.899994
# 7    2012-01-12   179.419998   179.490005   175.750000   175.929993
# ...         ...          ...          ...          ...          ...
# 2234 2020-11-17  3183.540039  3189.250000  3135.260010  3135.659912
# 2235 2020-11-18  3134.000000  3140.000000  3105.100098  3105.459961
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 1      177.509995  4205.2    4      1  2012
# 4      178.559998  5056.9    9      1  2012
# ...

# %%
len(query2)
# Out:
# 1105

# %%
query2[['Adj Close', 'Open']]
# Out:
#         Adj Close         Open
# 1      177.509995   179.210007
# 4      178.559998   182.759995
# 5      179.339996   181.100006
# 6      178.899994   179.639999
# 7      175.929993   179.419998
# ...           ...          ...
# 2234  3135.659912  3183.540039
# 2235  3105.459961  3134.000000
# 2237  3099.399902  3117.020020
# 2238  3098.389893  3116.699951
# 2241  3195.340088  3211.260010
#
# [1105 rows x 2 columns]

# %%
# filters for Year > 2015
filter1 = data['Year'] > 2015
filter1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2237     True
# 2238     True
# 2239     True
# 2240     True
# 2241     True
# Name: Year, Length: 2228, dtype: bool

# %%
#filter for Adj Close < open
filter2 = data['Adj Close'] < data['Open']
filter2
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2237     True
# 2238     True
# 2239    False
# 2240    False
# 2241     True
# Length: 2228, dtype: bool

# %%
result = data[filter1 & filter2]
result
# Out:
#            Date         Open         High          Low        Close  \
# 1006 2016-01-04   656.289978   657.719971   627.510010   636.989990
# 1007 2016-01-05   646.859985   646.909973   627.650024   633.789978
# 1009 2016-01-07   621.799988   630.000000   605.210022   607.940002
# 1010 2016-01-08   619.659973   624.140015   606.000000   607.049988
# 1012 2016-01-12   625.250000   625.989990   612.239990   617.890015
# ...         ...          ...          ...          ...          ...
# 2234 2020-11-17  3183.540039  3189.250000  3135.260010  3135.659912
# 2235 2020-11-18  3134.000000  3140.000000  3105.100098  3105.459961
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 1006   636.989990  9314.5    4      1  2016
# 1007   633.789978  5822.6    5      1  2016
# ...

# %%
len(result)
# Out:
# 616

# %%
result[['Open', 'Adj Close']]
# Out:
#              Open    Adj Close
# 1006   656.289978   636.989990
# 1007   646.859985   633.789978
# 1009   621.799988   607.940002
# 1010   619.659973   607.049988
# 1012   625.250000   617.890015
# ...           ...          ...
# 2234  3183.540039  3135.659912
# 2235  3134.000000  3105.459961
# 2237  3117.020020  3099.399902
# 2238  3116.699951  3098.389893
# 2241  3211.260010  3195.340088
#
# [616 rows x 2 columns]

# %%
result['Open'].sum()
# Out:
# 947142.829894

# %%
result['Adj Close'].sum()
# Out:
# 935936.638605

# %%
result['Open'].sum() - result['Adj Close'].sum()
# Out:
# 11206.19128899998

# %%
rs = result[['Adj Close','Year']].groupby('Year').count()
rs
# Out:
#       Adj Close
# Year
# 2016        127
# 2017        128
# 2018        124
# 2019        125
# 2020        112

# %%
rs.idxmax()
# Out:
# Adj Close    2017
# dtype: int64

# %%
rs.plot.bar(figsize=(10,8), y='Adj Close', fontsize=12,title='title')
plt.ylabel('Number of stocks')
# Out:
# Text(0, 0.5, 'Number of stocks')

# %%
rs = data[['Month', 'High','Low','Open','Adj Close']].groupby('Month').mean()
rs
# Out:
#               High          Low         Open    Adj Close
# Month
# 1       845.138624   826.699177   835.785055   837.217747
# 2       869.500417   848.818237   859.158765   859.137411
# 3       883.179059   860.221100   871.632875   873.045287
# 4       935.481024   913.718432   924.956487   925.537783
# 5       981.422476   964.186472   972.484422   973.608949
# 6      1030.305523  1010.421686  1020.797158  1020.935264
# 7      1117.510261  1090.640261  1105.218596  1105.226407
# 8      1124.288736  1103.972829  1114.122626  1114.643383
# 9      1137.103572  1110.570271  1126.507582  1123.582474
# 10     1134.387446  1105.711601  1122.155053  1119.413149
# 11     1114.245054  1089.462911  1102.558629  1102.657419
# 12      861.799519   842.490300   853.738857   851.398673

# %%
rs.plot(figsize=(10,8), y=['High','Low','Open','Adj Close'], fontsize=12,title='Compare ave of High/Low')
plt.ylabel('Ave of stock Prices')
# Out:
# Text(0, 0.5, 'Ave of stock Prices')

# %%
#find the months that have the highest and lowest number of volume
rs = data[['Month','Volume']].groupby('Month').sum().astype(int)
rs
# Out:
#        Volume
# Month
# 1      884620
# 2      846030
# 3      839584
# 4      890804
# 5      693382
# 6      671267
# 7      792035
# 8      633655
# 9      650017
# 10     897270
# 11     743073
# 12     647949

# %%
rs.min()
# Out:
# Volume    633655
# dtype: int32

# %%
rs.max()
# Out:
# Volume    897270
# dtype: int32

# %%
rs.idxmin()
# Out:
# Volume    8
# dtype: int64

# %%
rs.idxmax()
# Out:
# Volume    10
# dtype: int64

# %%
print(f"The month with the lowest volume is {rs.idxmin()[0]}, Volume {rs.min()[0]}")
# Out:
# The month with the lowest volume is 8, Volume 633655

# %%
print(f"The month with the higest volume is {rs.idxmax()[0]}, Volume {rs.max()[0]}")
# Out:
# The month with the higest volume is 10, Volume 897270

# %%
#find the dates that have the highesdt and lowest number of volume
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...

# %%
r = data[['Date','Volume']].groupby('Date').count()
r
# Out:
#             Volume
# Date
# 2012-01-03       1
# 2012-01-04       1
# 2012-01-05       1
# 2012-01-06       1
# 2012-01-09       1
# ...            ...
# 2020-11-20       1
# 2020-11-23       1
# 2020-11-24       1
# 2020-11-25       1
# 2020-11-27       1
#
# [2228 rows x 1 columns]

# %%
rs = data['Volume']
rs
# Out:
# 0       5110.8
# 1       4205.2
# 2       3809.1
# 3       7008.4
# 4       5056.9
#          ...
# 2237    3374.4
# 2238    4708.9
# 2239    3602.1
# 2240    3790.4
# 2241    2392.9
# Name: Volume, Length: 2228, dtype: float64

# %%
s = rs.idxmin()
s
# Out:
# 2007

# %%
l = rs.idxmax()
l
# Out:
# 773

# %%
data.iloc[s]['Date'].date()
# Out:
# datetime.date(2020, 1, 15)

# %%
data.iloc[l]['Date'].date()
# Out:
# datetime.date(2015, 2, 20)

# %%
print(f"The date with the lowest volume {data.iloc[s]['Date'].date()}, Volume {data.iloc[s]['Volume'].astype(int)}")
# Out:
# The date with the lowest volume 2020-01-15, Volume 2896

# %%
print(f"The date with the higest volume {data.iloc[l]['Date'].date()}, Volume {data.iloc[l]['Volume'].astype(int)}")
# Out:
# The date with the higest volume 2015-02-20, Volume 3258

# %%
#find the month and day that has the lowesty (adj close) closing ave price
rs = data[['Month', 'Day', 'Adj Close']].groupby(['Month','Day']).mean()
rs
# Out:
#             Adj Close
# Month Day
# 1     2    931.658335
#       3    881.009992
#       4    769.301659
#       5    624.636002
#       6    700.508339
# ...               ...
# 12    27   988.581681
#       28   871.326001
#       29   735.157494
#       30   797.900000
#       31   830.951660
#
# [363 rows x 1 columns]

# %%
rs.idxmax()
# Out:
# Adj Close    (9, 1)
# dtype: object

# %%
rs['Adj Close'].min()
# Out:
# 366.105011

# %%
rs.idxmin()
# Out:
# Adj Close    (2, 29)
# dtype: object

# %%
rs['Adj Close'].max()
# Out:
# 1436.1325302500002

# %%
print(f"The month and day with the lowest closing price is {rs.idxmin()[0]}, volume {rs['Adj Close'].min().astype(int)}")
# Out:
# The month and day with the lowest closing price is (2, 29), volume 366

# %%
print(f"The month and day with the highest closing price is {rs.idxmax()[0]}, volume {rs['Adj Close'].max().astype(int)}")
# Out:
# The month and day with the highest closing price is (9, 1), volume 1436

# %%
#show the closing, open, year, month, day of the highest volume
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...

# %%
r = data.iloc[data['Volume'].idxmax()]
r
# Out:
# Date         2015-02-20 00:00:00
# Open                      378.62
# High                       383.7
# Low                       375.84
# Close                     383.66
# Adj Close                 383.66
# Volume                      3258
# Day                           20
# Month                          2
# Year                        2015
# Name: 787, dtype: object

# %%
print(r['Close'], r['Open'], r['Year'], r['Month'], r['Day'], r['Volume'])
# Out:
# 383.660004 378.619995 2015 2 20 3258.0

# %%
data.iloc[2000]
# Out:
# Date         2020-01-06 00:00:00
# Open                        1860
# High                     1903.69
# Low                         1860
# Close                    1902.88
# Adj Close                1902.88
# Volume                    4061.8
# Day                            6
# Month                          1
# Year                        2020
# Name: 2014, dtype: object

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2012-01-03   175.889999   179.479996   175.550003   179.029999
# 1    2012-01-04   179.210007   180.500000   176.070007   177.509995
# 2    2012-01-05   175.940002   178.250000   174.050003   177.610001
# 3    2012-01-06   178.070007   184.649994   177.500000   182.610001
# 4    2012-01-09   182.759995   184.369995   177.000000   178.559998
# ...         ...          ...          ...          ...          ...
# 2237 2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 2238 2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 2239 2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
# 2240 2020-11-25  3141.870117  3198.000000  3140.260010  3185.070068
# 2241 2020-11-27  3211.260010  3216.189941  3190.050049  3195.340088
#
#         Adj Close  Volume  Day  Month  Year
# 0      179.029999  5110.8    3      1  2012
# 1      177.509995  4205.2    4      1  2012
# ...
